# %%
#pip install opencv-python
#python-m pip install opencv-python
#python3-m pip install opencv-python

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
#grey images this code not work in colab it works in jupiter
cv2=imshow(img_grey)
cv2.waitkey=100
cv2.distroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-d44f23cda419> in <cell line: 2>()
#       1 #grey images this code not work in colab it works in jupiter
# ----> 2 cv2=imshow(img_grey)
#       3 cv2.waitkey=100
#       4 cv2.distroyAllWindows()
#
# NameError: name 'imshow' is not defined

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",0)
cv2_imshow(img_grey)
print(type(img_grey))
print(img_grey.shape)

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",1)
cv2_imshow(img_grey)

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",-1)
cv2_imshow(img_grey)

# %%
#colored images
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/color.webp",0)
cv2_imshow(img_grey)
print(type(img_grey))
print(img_grey.shape)

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/color.webp",1)
cv2_imshow(img_grey)
print(type(img_grey))
print(img_grey.shape)

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/color.webp",-1)
cv2_imshow(img_grey)

# %%
img_grey=np.zeros((128,128))
cv2_imshow(img_grey)

# %%
img_grey=255*np.ones((128,128))
cv2_imshow(img_grey)

# %%
img_grey=215*np.ones((128,128))
cv2_imshow(img_grey)

# %%
img_grey=145*np.ones((128,128))
cv2_imshow(img_grey)

# %%
img_grey=125*np.ones((428,428))
cv2_imshow(img_grey)

# %%
img_carr=255*np.ones((128,128))
black=np.zeros((64,64))
dark_grey=100*np.ones((64,64))
light_grey=200*np.ones((64,64))
white=255*np.ones((64,64))

img_carr[0:64,0:64]=black
img_carr[0:64,64:128]=dark_grey
img_carr[64:128,0:64]=light_grey
img_carr[64:128,64:128]=white

cv2_imshow(img_carr)

# %%
img_grey=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",0)
cv2_imshow(img_grey)
img_part = img_grey
part_1 = img_part[200:300,500:600]
img_part[400:500,600:700]= part_1
cv2_imshow(img_part)

# %%
cv2.imwrite("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",img_grey)

# %%
#colored images
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
#img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,1]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
#img_color_carr[:,:,0]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,2]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,1]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
#mg_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,1]=255*np.ones((128,128))
img_color_carr[:,:,2]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=255*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,2]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,1]=255*np.ones((128,128))
img_color_carr[:,:,2]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=100*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
img_color_carr[:,:,2]=167*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
img_color_carr[:,:,0]=215*np.ones((128,128))
img_color_carr[:,:,1]=115*np.ones((128,128))
#img_color_carr[:,:,0]=255*np.ones((128,128))
cv2_imshow(img_color_carr)

# %%
img_color_carr=np.ones((128,128,3))
height, width, _ = img_color_carr.shape
half_height = height // 2
half_width = width // 2

img_color_carr[:half_height, :half_width, :] = [255, 0, 0]
img_color_carr[:half_height, half_width:, :] = [0, 255, 0]
img_color_carr[half_height:, :half_width, :] = [0, 0, 255]
img_color_carr[half_height:, half_width:, :] = [25, 25, 0]
cv2_imshow(img_color_carr)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_color=cv2.imread("/content/drive/MyDrive/10th/open cv_images/input_image-1.webp",1)
cv2_imshow(img_color)
print(type(img_color))
print(img_color.shape)
b=img_color[:,:,0]
g=img_color[:,:,1]
r=img_color[:,:,2]
print(img_color.shape,b.shape,g.shape,r.shape)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>
# <class 'numpy.ndarray'>
# (333, 500, 3)
# (333, 500, 3) (333, 500) (333, 500) (333, 500)
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>

# %%
img_color=cv2.imread("/content/drive/MyDrive/10th/open cv_images/input_image-1.webp",1)
cv2_imshow(img_color)
print(type(img_color))
print(img_color.shape)
b,g,r=cv2.split(img_color)

print(img_color.shape,b.shape,g.shape,r.shape)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>
# <class 'numpy.ndarray'>
# (333, 500, 3)
# (333, 500, 3) (333, 500) (333, 500) (333, 500)
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>

# %% [markdown]
# merge()**bold text*

# %%
merged_img=cv2.merge((b,g,r))
cv2_imshow(merged_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %% [markdown]
# **resize:**

# %%
resized_img=cv2.resize(img_color,None,fx=0.5,fy=1/2)
print(img_color.shape)
cv2_imshow(img_color)
print(resized_img.shape)
cv2_imshow(resized_img)
# Out:
# (333, 500, 3)
# <PIL.Image.Image image mode=RGB size=500x333>
# (166, 250, 3)
# <PIL.Image.Image image mode=RGB size=250x166>

# %%
resized_img=cv2.resize(img_color,(240,150))
print(img_color.shape)
cv2_imshow(img_color)
print(resized_img.shape)
cv2_imshow(resized_img)
# Out:
# (333, 500, 3)
# <PIL.Image.Image image mode=RGB size=500x333>
# (150, 240, 3)
# <PIL.Image.Image image mode=RGB size=240x150>

# %% [markdown]
# **rotate**

# %%
rotate_img=cv2.rotate(resized_img,cv2.ROTATE_180)
print(resized_img.shape)
cv2_imshow(resized_img)
print(rotate_img.shape)
cv2_imshow(rotate_img)
# Out:
# (150, 240, 3)
# <PIL.Image.Image image mode=RGB size=240x150>
# (150, 240, 3)
# <PIL.Image.Image image mode=RGB size=240x150>

# %% [markdown]
# **Adding a line**

# %%
img_gre=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",1)
cv2_imshow(img_gre)
new_img=cv2.line(img_gre,(0,0),(300,300),color=7)
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=418x626>
# <PIL.Image.Image image mode=RGB size=418x626>

# %%
img_gre=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",1)
cv2_imshow(img_gre)
new_img=cv2.rectangle(img_gre,(0,0),(200,200),color=7)
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=418x626>
# <PIL.Image.Image image mode=RGB size=418x626>

# %%
img_gre=cv2.imread("/content/drive/MyDrive/10th/open cv_images/vertical-grayscale-shot-grassy-field-with-blurred-cross_.webp",1)
cv2_imshow(img_gre)
new_img=cv2.circle(img_gre,(100,100),50,color=7,thickness=2)
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=418x626>
# <PIL.Image.Image image mode=RGB size=418x626>

# %%
noisy_img=cv2.imread("/content/drive/MyDrive/10th/open cv_images/input_image-1.webp",0)
cv2_imshow(noisy_img)
print(noisy_img.shape)
kernal=np.ones((3,3),dtype=np.float32)/9
denoised_img2=cv2.Canny(noisy_img,100,200)
cv2_imshow(denoised_img2)
# Out:
# <PIL.Image.Image image mode=L size=500x333>
# (333, 500)
# <PIL.Image.Image image mode=L size=500x333>

# %%
noisy_img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/Noise_salt_and_pepper.webp",0)
cv2_imshow(noisy_img)
print(noisy_img.shape)
kernel=np.ones((3,3),dtype=np.float32)/9
denoised_img1=cv2.filter2D(noisy_img,-1,kernel)
cv2_imshow(denoised_img1)
# Out:
# <PIL.Image.Image image mode=L size=320x428>
# (428, 320)
# <PIL.Image.Image image mode=L size=320x428>
